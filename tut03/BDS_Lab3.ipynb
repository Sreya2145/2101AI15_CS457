# %%
import re

# Function to check if password meets the required criteria
def validate_password(password, selected_criteria):
    # Skip validation if password is too short
    if len(password) < 8:
        print(f"'{password}' -> Invalid password. Less than 8 characters.")
        return

    # Define criteria flags
    has_upper = any(char.isupper() for char in password)
    has_lower = any(char.islower() for char in password)
    has_digit = any(char.isdigit() for char in password)
    has_special = bool(re.search(r"[!@#]", password))  # Only !, @, # allowed

    # Check for invalid special characters
    if re.search(r"[^a-zA-Z0-9!@#]", password):
        print(f"'{password}' -> Invalid password. Contains unallowed special characters.")
        return

    # Map criteria to their respective flags
    criteria_map = {
        1: has_upper,
        2: has_lower,
        3: has_digit,
        4: has_special
    }

    # Check if the password meets all selected criteria
    missing_criteria = [f"Missing {desc}" for key, desc in {
        1: "Uppercase letters",
        2: "Lowercase letters",
        3: "Numbers",
        4: "Special characters (!, @, #)"
    }.items() if key in selected_criteria and not criteria_map[key]]

    if missing_criteria:
        print(f"'{password}' -> Invalid password. {', '.join(missing_criteria)}")
    else:
        print(f"'{password}' -> Valid password.")

# Get user-selected criteria
try:
    selected_criteria = list(map(int, input("Enter the criteria numbers (comma-separated) to check (1-4): ").split(',')))
    valid_criteria = {1, 2, 3, 4}

    if not set(selected_criteria).issubset(valid_criteria):
        print("Invalid input! Please enter numbers between 1 and 4.")
    else:
        # Sample password list
        password_list = [
            "abc12345",
            "abc",
            "123456789",
            "abcdefg$",
            "abcdefgABHD!@313",
            "abcdefgABHD$$!@313"
        ]

        # Validate each password
        print("\nPassword Validation Results:")
        for password in password_list:
            validate_password(password, selected_criteria)

except ValueError:
    print("Invalid input! Please enter numbers separated by commas.")
# Out:
# Enter the criteria numbers (comma-separated) to check (1-4): 1,2,3,4
#
# Password Validation Results:
# 'abc12345' -> Invalid password. Missing Uppercase letters, Missing Special characters (!, @, #)
# 'abc' -> Invalid password. Less than 8 characters.
# '123456789' -> Invalid password. Missing Uppercase letters, Missing Lowercase letters, Missing Special characters (!, @, #)
# 'abcdefg$' -> Invalid password. Contains unallowed special characters.
# 'abcdefgABHD!@313' -> Valid password.
# 'abcdefgABHD$$!@313' -> Invalid password. Contains unallowed special characters.

# %%
import re

# Function to check if a password meets the required criteria
def validate_password(password, selected_criteria):
    password = password.strip()  # Remove leading/trailing spaces

    # Skip validation if password is too short
    if len(password) < 8:
        return "Invalid (Less than 8 characters)"

    # Define criteria flags
    has_upper = any(char.isupper() for char in password)
    has_lower = any(char.islower() for char in password)
    has_digit = any(char.isdigit() for char in password)
    has_special = bool(re.search(r"[!@#]", password))  # Only !, @, # allowed

    # Check for unallowed special characters
    if re.search(r"[^a-zA-Z0-9!@#]", password):
        return "Invalid (Contains unallowed special characters)"

    # Map criteria to their respective flags
    criteria_map = {
        1: has_upper,
        2: has_lower,
        3: has_digit,
        4: has_special
    }

    # Check if all selected criteria are met
    missing_criteria = [desc for key, desc in {
        1: "Uppercase letters",
        2: "Lowercase letters",
        3: "Numbers",
        4: "Special characters (!, @, #)"
    }.items() if key in selected_criteria and not criteria_map[key]]

    return "Valid" if not missing_criteria else f"Invalid (Missing {', '.join(missing_criteria)})"


# Get user-selected criteria
try:
    selected_criteria = list(map(int, input("Enter the criteria numbers (comma-separated) to check (1-4): ").split(',')))
    valid_criteria = {1, 2, 3, 4}

    if not set(selected_criteria).issubset(valid_criteria):
        print("Invalid input! Please enter numbers between 1 and 4.")
    else:
        # Open and read passwords from file
        try:
            with open("input.txt", "r") as file:
                passwords = file.readlines()

            valid_count = 0
            invalid_count = 0

            print("\nPassword Validation Results:")
            for password in passwords:
                result = validate_password(password, selected_criteria)
                print(f"'{password.strip()}' -> {result}")
                if result == "Valid":
                    valid_count += 1
                else:
                    invalid_count += 1

            # Display total count of valid and invalid passwords
            print("\nSummary:")
            print(f"Total Valid Passwords: {valid_count}")
            print(f"Total Invalid Passwords: {invalid_count}")

        except FileNotFoundError:
            print("Error: input.txt not found. Please create the file and add passwords.")

except ValueError:
    print("Invalid input! Please enter numbers separated by commas.")
# Out:
# Enter the criteria numbers (comma-separated) to check (1-4): 1,2,3,4
#
# Password Validation Results:
# '4f!2mtf!X9' -> Valid
# 'GEVYYonr7D' -> Invalid (Missing Special characters (!, @, #))
# 'akR@i9YSbZl' -> Valid
# 'JcU9S' -> Invalid (Less than 8 characters)
# 'rneuP8' -> Invalid (Less than 8 characters)
# 'eAzxhAGc!a4SO' -> Valid
# 'vkV806H@M' -> Valid
# 'kRPH9Xh' -> Invalid (Less than 8 characters)
# 'siy2f@ZJHqr1!' -> Valid
# 'shNtOTfk' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'rHMuFEreR8djC' -> Invalid (Missing Special characters (!, @, #))
# 'gV#GKBWlaLX' -> Invalid (Missing Numbers)
# 'do5lCU' -> Invalid (Less than 8 characters)
# 'k4u5lY5Qp' -> Invalid (Missing Special characters (!, @, #))
# 'cJOpqz7sIO#Z#L6' -> Valid
# 'SVLtd8KKKVEp!' -> Valid
# 'gQN6eh1' -> Invalid (Less than 8 characters)
# 'CGO7ulq5la#a0E' -> Valid
# 'i0hy2GxezTKDd' -> Invalid (Missing Special characters (!, @, #))
# '2ntj!y!qhIp' -> Valid
# '91yEw#2o2EcD' -> Valid
# '7@r2W8@@qn8HdA' -> Valid
# '!M#9w' -> Invalid (Less than 8 characters)
# 'anOo7Wql7NP' -> Invalid (Missing Special characters (!, @, #))
# 'HN42M0#U' -> Invalid (Missing Lowercase letters)
# 'gIr1lkIDvhl' -> Invalid (Missing Special characters (!, @, #))
# 'kW8v@wo' -> Invalid (Less than 8 characters)
# 'HiOPO' -> Invalid (Less than 8 characters)
# 'xH!xJ993' -> Valid
# 'Lbd9q5eR#' -> Valid
# 'NvCN6' -> Invalid (Less than 8 characters)
# 'M7XY@Gxa2H4QoT' -> Valid
# 'VYr#mgBty!37' -> Valid
# 'h#BrJr2DLS' -> Valid
# 'akHJd6uXl#U6' -> Valid
# 'd6!RXAwPR' -> Valid
# 'subxAsgtk' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'el3x@#ZFn4' -> Valid
# '72WIts#Yf' -> Valid
# '#GUgIaa' -> Invalid (Less than 8 characters)
# '9eMVZ5i8e' -> Invalid (Missing Special characters (!, @, #))
# 'xbmGSy' -> Invalid (Less than 8 characters)
# 'S#6thyN' -> Invalid (Less than 8 characters)
# '9A@di37Zin' -> Valid
# '9UR7KI0sgQM3Op' -> Invalid (Missing Special characters (!, @, #))
# 'HDp!L' -> Invalid (Less than 8 characters)
# 'saVvBV@2wCmu#' -> Valid
# '4sDPy6HTuB' -> Invalid (Missing Special characters (!, @, #))
# '5@j1WFKCw0c6yX' -> Valid
# 'q!Dgljx@6XxZXb' -> Valid
# 'X07C#bG5w!' -> Valid
# '43MY7x' -> Invalid (Less than 8 characters)
# '#qA0BPQoB2Z6K8!' -> Valid
# 'Y9h8v' -> Invalid (Less than 8 characters)
# 'r@O#Os6ykhy@' -> Valid
# '3Xk8OZ' -> Invalid (Less than 8 characters)
# 'jty#e' -> Invalid (Less than 8 characters)
# '3xP15GSA4OQsC' -> Invalid (Missing Special characters (!, @, #))
# 'mMTHJQ8@aT' -> Valid
# '!CxN!' -> Invalid (Less than 8 characters)
# 'Z@4O8nPYlz' -> Valid
# 'zxNX#uGj#DqhoE#' -> Invalid (Missing Numbers)
# 'CMdg#7ZtB' -> Valid
# 'fC@15W' -> Invalid (Less than 8 characters)
# 'QeePBwt9@' -> Valid
# 'z!SA9Ij2' -> Valid
# '2#0KXeetC!' -> Valid
# 'JigiD' -> Invalid (Less than 8 characters)
# 'Z!d#gcP#d1eEJV' -> Valid
# 'hAPsb' -> Invalid (Less than 8 characters)
# 'Bh!FTQZHP0s4Q4' -> Valid
# 'S!jAZlQ' -> Invalid (Less than 8 characters)
# 'Ax83g#hg' -> Valid
# 'Z6prwqHaTQg9iC@' -> Valid
# 'Z@Ti1' -> Invalid (Less than 8 characters)
# 'h2Z@0' -> Invalid (Less than 8 characters)
# 'fYJKypN6J51' -> Invalid (Missing Special characters (!, @, #))
# 'B88Vh9j#O7H' -> Valid
# 'pxpn4e!c1o@Q3VZ' -> Valid
# 'Z#@J#EcNTqEM' -> Invalid (Missing Numbers)
# 'Wr!3tU' -> Invalid (Less than 8 characters)
# 'JuYlvY!DIA3!p' -> Valid
# '@92Ja13snK9p3q' -> Valid
# '52Rd5Wqp2zhe' -> Invalid (Missing Special characters (!, @, #))
# 'AckstO3eoc' -> Invalid (Missing Special characters (!, @, #))
# 'rXd1ZWM' -> Invalid (Less than 8 characters)
# 'gpqqx' -> Invalid (Less than 8 characters)
# 'te0fzR3SdvT22A' -> Invalid (Missing Special characters (!, @, #))
# 'a7RvZ' -> Invalid (Less than 8 characters)
# 'f8V#ih' -> Invalid (Less than 8 characters)
# 'tOdxzD9#l' -> Valid
# '#iT1D4X' -> Invalid (Less than 8 characters)
# 'WERE7y' -> Invalid (Less than 8 characters)
# 'c30#KHECBV' -> Valid
# 'WGSc0!nfBq' -> Valid
# 'R#!Hn!U1' -> Valid
# 'Re3Y6yPZ#buNF7' -> Valid
# '!dIz5Ws' -> Invalid (Less than 8 characters)
# '7mF@hJCcD8P' -> Valid
# 'oj39tX1' -> Invalid (Less than 8 characters)
# 'ygZpe' -> Invalid (Less than 8 characters)
# '#2IsPvEN3' -> Valid
# 'Xs69s2m' -> Invalid (Less than 8 characters)
# 'i3YqRJ4!' -> Valid
# '3zJvDt7' -> Invalid (Less than 8 characters)
# 'cs@Og' -> Invalid (Less than 8 characters)
# 'o5mixuV37' -> Invalid (Missing Special characters (!, @, #))
# 'uI!D8xk9q' -> Valid
# 'arlDRJAaSdh#' -> Invalid (Missing Numbers)
# 'n9#aSwIX89UD' -> Valid
# 'qRlIUWg5' -> Invalid (Missing Special characters (!, @, #))
# 'D!m60QC7' -> Valid
# 'FZnw05xB' -> Invalid (Missing Special characters (!, @, #))
# 'J9U#0ehNY' -> Valid
# 'pH0TP2eU' -> Invalid (Missing Special characters (!, @, #))
# 'WFQ!T7nKYFw!' -> Valid
# 'ctXpj@pvxjUFX' -> Invalid (Missing Numbers)
# 'bVf2j6Ib' -> Invalid (Missing Special characters (!, @, #))
# 'i@bF9wI#BT4!5!' -> Valid
# 'c9EAmBk@o6I#' -> Valid
# 'Runhi1b8y8wTuL4' -> Invalid (Missing Special characters (!, @, #))
# 'q0igv22#8zs0a' -> Invalid (Missing Uppercase letters)
# 'pE@Z2OXID' -> Valid
# 'ZAQ9qTGuI!hFvJ' -> Valid
# 'LKwE7A19jQqs' -> Invalid (Missing Special characters (!, @, #))
# 'YjbdAr@1so' -> Valid
# '2t1wH5@xb@' -> Valid
# '2hXP3SFy8T08' -> Invalid (Missing Special characters (!, @, #))
# 'MNT75Y@FtRp' -> Valid
# 'ld1mJ' -> Invalid (Less than 8 characters)
# 'lDkDS3pWD!t' -> Valid
# 'ReR3GOPc6Q7Pd' -> Invalid (Missing Special characters (!, @, #))
# '3DaGQ8EAs!#' -> Valid
# 'c2UPKYJ' -> Invalid (Less than 8 characters)
# 'qX3sYIaOQV#f7wK' -> Valid
# 'oR5Pb#tR' -> Valid
# 'o5i9C6PFLj@NnY' -> Valid
# 'oUyDrHU' -> Invalid (Less than 8 characters)
# 'N8tG6UVS6QF3' -> Invalid (Missing Special characters (!, @, #))
# 'cN!@3Y1JHt' -> Valid
# 'D!ql1' -> Invalid (Less than 8 characters)
# '50zkGu62gcQS!' -> Valid
# 'Xvk#9kne' -> Valid
# 'Byd!zkk' -> Invalid (Less than 8 characters)
# 'Les@W!WqA@l1' -> Valid
# 'V2uuEfQc' -> Invalid (Missing Special characters (!, @, #))
# 'Xev@nPKqls' -> Invalid (Missing Numbers)
# 'zHQ2N7r#' -> Valid
# 'M314vnH' -> Invalid (Less than 8 characters)
# 'HLM9#iT10L!GU' -> Valid
# 'CtmFChE4Ni2Vwbw' -> Invalid (Missing Special characters (!, @, #))
# 'pmcT9!L' -> Invalid (Less than 8 characters)
# 'CRIetG5l@c1Zp' -> Valid
# '4RN1OM0fJk!' -> Valid
# 'ifJScKVc' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'XWrnJS#5' -> Valid
# 'c505QUs#Js' -> Valid
# 'x@rC7LF' -> Invalid (Less than 8 characters)
# 'G7n6Nk' -> Invalid (Less than 8 characters)
# '@5DZspfo@bYID5' -> Valid
# '#P5yJthJ5vw' -> Valid
# '5i9PSFa0' -> Invalid (Missing Special characters (!, @, #))
# '@vJyEB2tRDqdg' -> Valid
# '9a7Z3ry#pFD03Gj' -> Valid
# '0xmPQjl32fCDL2' -> Invalid (Missing Special characters (!, @, #))
# 'SVLfK7hGL!' -> Valid
# 'uulwjtrTVmC' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'hMu6A5ZOTs!3' -> Valid
# '2gw#v' -> Invalid (Less than 8 characters)
# 'fF7fbv' -> Invalid (Less than 8 characters)
# '0wt1yhsh#TppW' -> Valid
# 'UXNF5mVOescC' -> Invalid (Missing Special characters (!, @, #))
# 'X!jwXf0' -> Invalid (Less than 8 characters)
# '3q6bAeCgcb75hbD' -> Invalid (Missing Special characters (!, @, #))
# '77RnP' -> Invalid (Less than 8 characters)
# 'R9zDB40riNdu' -> Invalid (Missing Special characters (!, @, #))
# 'qAkv5qd' -> Invalid (Less than 8 characters)
# 'YHtkzhbAyC' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'CBC9iaXRE#4' -> Valid
# 'hVd@v' -> Invalid (Less than 8 characters)
# '!tAE6rTX8XH27p' -> Valid
# 'QTi41vyPn' -> Invalid (Missing Special characters (!, @, #))
# '!NPrG3' -> Invalid (Less than 8 characters)
# '6mhZ4' -> Invalid (Less than 8 characters)
# 'K6iT6u' -> Invalid (Less than 8 characters)
# '03lAA@WR#pU' -> Valid
# '8ZQoI5onbzza0J0' -> Invalid (Missing Special characters (!, @, #))
# 'b!Sop5' -> Invalid (Less than 8 characters)
# 'usv8!c96Dl' -> Valid
# 'Dp49Az' -> Invalid (Less than 8 characters)
# 'me@nK10N5qPU' -> Valid
# 'z@5oo3T1hTzC' -> Valid
# 'nBi@9rbfO2VMhgq' -> Valid
# 'wPW5Nl89' -> Invalid (Missing Special characters (!, @, #))
# 'OYEMSLCDNmW7' -> Invalid (Missing Special characters (!, @, #))
# 'Q!hLYy68' -> Valid
# '#KD1IMj#x8' -> Valid
# 'e40lCx#GpCz0' -> Valid
# 'NRRI!' -> Invalid (Less than 8 characters)
# 'bethADEz' -> Invalid (Missing Numbers, Special characters (!, @, #))
# '!HEDH2G4p' -> Valid
# 'wFCtp!H1Mi' -> Valid
# 'jmT8XZXNmz2EHDR' -> Invalid (Missing Special characters (!, @, #))
# 'hq@xzy!zC' -> Invalid (Missing Numbers)
# 'c@#6W7u4' -> Valid
# '0OhV8@' -> Invalid (Less than 8 characters)
# '8XP@ASjJuzlS' -> Valid
# 'TKM5zUS0!p518' -> Valid
# '6YA5A6DN1ptE' -> Invalid (Missing Special characters (!, @, #))
# 'jXSI6K' -> Invalid (Less than 8 characters)
# 'mXf2fjhdLvI#i' -> Valid
# 'baQPh@#B#5v' -> Valid
# 'Sv3C!SlhbvoP' -> Valid
# 'aWHz#' -> Invalid (Less than 8 characters)
# 'dCg5#' -> Invalid (Less than 8 characters)
# 'h@fIwjPM' -> Invalid (Missing Numbers)
# '442wMACFQZHdB' -> Invalid (Missing Special characters (!, @, #))
# 'R@KzMO!h3zd8' -> Valid
# '@kiXr9zAM' -> Valid
# 'E1VVy1842g48L' -> Invalid (Missing Special characters (!, @, #))
# 'L@ho1' -> Invalid (Less than 8 characters)
# 'AsJSUCnIeLP8P' -> Invalid (Missing Special characters (!, @, #))
# 'o233B#R@Uj6#gDw' -> Valid
# 'Z@bW#ETU' -> Invalid (Missing Numbers)
# 'j2!QtgvP7' -> Valid
# 'y13tVBHjR' -> Invalid (Missing Special characters (!, @, #))
# 'q3kpOg8bO!AE6#' -> Valid
# 'XTk8o3' -> Invalid (Less than 8 characters)
# 'KnYxvRc@5' -> Valid
# 'q#Q4pq!15vPNouM' -> Valid
# 'Su@N4tXCa' -> Valid
# '6Y#2Ld0@' -> Valid
# '9s3t5#28nd' -> Invalid (Missing Uppercase letters)
# 'rK4xCipf!KW7' -> Valid
# '9sR6HVfU!HWX' -> Valid
# 'zP7qQZ4IIlq' -> Invalid (Missing Special characters (!, @, #))
# 'A12Sgx66cfVGnk' -> Invalid (Missing Special characters (!, @, #))
# 'TfJYMpQks' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'WhARca2' -> Invalid (Less than 8 characters)
# 'ymTKCh!k!' -> Invalid (Missing Numbers)
# 'Hm#kAWVXgUv7k' -> Valid
# 'I98jSFo' -> Invalid (Less than 8 characters)
# 'Ijv#QY' -> Invalid (Less than 8 characters)
# '0DA6sUuici' -> Invalid (Missing Special characters (!, @, #))
# 'cKGMnUT2im@c8' -> Valid
# 'DOftgpsJj!Y#' -> Invalid (Missing Numbers)
# 'z6pkqxf7z7z7cPY' -> Invalid (Missing Special characters (!, @, #))
# 'Ro#JXwDLbg#F' -> Invalid (Missing Numbers)
# '91hR#THk' -> Valid
# 'O7Clb' -> Invalid (Less than 8 characters)
# 'gxbrv#M8SKo9jCY' -> Valid
# 'Jb#u!' -> Invalid (Less than 8 characters)
# 'BKneN63' -> Invalid (Less than 8 characters)
# '#Dj69B' -> Invalid (Less than 8 characters)
# '@ay44FTF' -> Valid
# 'Q@9GptVx9o' -> Valid
# 'Ql4g!MjWt@' -> Valid
# 'r1N8939Xs' -> Invalid (Missing Special characters (!, @, #))
# 'RN6rGTvg84vs' -> Invalid (Missing Special characters (!, @, #))
# 'r@2daPSsqL' -> Valid
# 'u@iCk8oN!GDRu' -> Valid
# 'cVUmB2e5lMpW#l' -> Valid
# 'y9ICZ1' -> Invalid (Less than 8 characters)
# 'XysckY1D' -> Invalid (Missing Special characters (!, @, #))
# 'LDo9zC' -> Invalid (Less than 8 characters)
# 'HHw3i' -> Invalid (Less than 8 characters)
# 'JN6DgRbMd@' -> Valid
# 'Uq0RS' -> Invalid (Less than 8 characters)
# 'VD0R#pGPZ63gC8F' -> Valid
# 'pV73o040' -> Invalid (Missing Special characters (!, @, #))
# 'B!3he' -> Invalid (Less than 8 characters)
# 'APgJW!zKE2TehBw' -> Valid
# 'Y0VkhiNS@Eso1' -> Valid
# 'HMI3F' -> Invalid (Less than 8 characters)
# '#Rr2miQ1Z4' -> Valid
# 'F9czN1!!g' -> Valid
# 'kbeN3SJ2QM' -> Invalid (Missing Special characters (!, @, #))
# 'InDenW@' -> Invalid (Less than 8 characters)
# 's2VXQk8KCW#94tl' -> Valid
# 'SvNWR@' -> Invalid (Less than 8 characters)
# 'lUjC2!U' -> Invalid (Less than 8 characters)
# 'BxOOst!iquM9A9' -> Valid
# '16TKJw#9' -> Valid
# 'QtlXn@I' -> Invalid (Less than 8 characters)
# 'y86jn!ho2#' -> Invalid (Missing Uppercase letters)
# 'csL00y5' -> Invalid (Less than 8 characters)
# '8gStpY' -> Invalid (Less than 8 characters)
# 'OLtidNT7ZHWpQB' -> Invalid (Missing Special characters (!, @, #))
# 'QEJO1Wou09NNz9' -> Invalid (Missing Special characters (!, @, #))
# 'Zaf8f1Gq6PP@' -> Valid
# 'AJ63@e' -> Invalid (Less than 8 characters)
# 'Xqql2' -> Invalid (Less than 8 characters)
# 'lAMz10!YiT7Wv' -> Valid
# '@ax1NhV' -> Invalid (Less than 8 characters)
# '9lnYeH#VLjU' -> Valid
# 'CquJ0jE' -> Invalid (Less than 8 characters)
# 'kMsuVA9HUP@See' -> Valid
# 'k!DD7' -> Invalid (Less than 8 characters)
# '5mhNba#4U96Sn' -> Valid
# '56OEYYa#uJEdPq9' -> Valid
# '!s@B2n' -> Invalid (Less than 8 characters)
# '20pL0o3BB' -> Invalid (Missing Special characters (!, @, #))
# 'u#LAScO0qf7GL!9' -> Valid
# 'vQYpT' -> Invalid (Less than 8 characters)
# 'RiL1Y7E' -> Invalid (Less than 8 characters)
# 'w8eZ!ME4b' -> Valid
# 'HYRDv03s8' -> Invalid (Missing Special characters (!, @, #))
# 'fcMu9ynUCGB' -> Invalid (Missing Special characters (!, @, #))
# '#YJY3o8!gWa' -> Valid
# 'a2!UX#dVXX' -> Valid
# 'Vu7#Q5' -> Invalid (Less than 8 characters)
# 'cpg#IIP63!v4D3r' -> Valid
# 'e#Clu4' -> Invalid (Less than 8 characters)
# '!SrEJuwZF' -> Invalid (Missing Numbers)
# 's!h!NLg7' -> Valid
# 'Lz73@2X5@TbYU' -> Valid
# 'Y1AR@b' -> Invalid (Less than 8 characters)
# 'QkHNIah' -> Invalid (Less than 8 characters)
# '9025uU@g3' -> Valid
# 'CuB0PQie!lomOuS' -> Valid
# 'ABU1sC' -> Invalid (Less than 8 characters)
# 'jFSjL' -> Invalid (Less than 8 characters)
# '@ETngRK@wW' -> Invalid (Missing Numbers)
# 'Z0ub2hWKOLlTK' -> Invalid (Missing Special characters (!, @, #))
# '1k9W3qf#AWoAVq' -> Valid
# 'ix0s#zV3OBW4Rpi' -> Valid
# '1XXXyGM45nXr5' -> Invalid (Missing Special characters (!, @, #))
# 'XGctVRlcY6bC5' -> Invalid (Missing Special characters (!, @, #))
# 'Z1wpDn8T2zn' -> Invalid (Missing Special characters (!, @, #))
# 'vxHLsgvafd1#Wd' -> Valid
# '1ElsW' -> Invalid (Less than 8 characters)
# 'jglonVbw' -> Invalid (Missing Numbers, Special characters (!, @, #))
# '7wCN@uYW@' -> Valid
# 'Rf#iNxZb@o' -> Invalid (Missing Numbers)
# 'PrjVTNmC#wr2' -> Valid
# 'p#T@TY7' -> Invalid (Less than 8 characters)
# 'L@vCaJriXaYy' -> Invalid (Missing Numbers)
# 'O6dd!23UgvWW' -> Valid
# 'VcjHD5DeBb' -> Invalid (Missing Special characters (!, @, #))
# 'K8Iln#ZKDOB9e8o' -> Valid
# '@NMghf9b' -> Valid
# '#d!@2OQkeM' -> Valid
# '5G2ug4oy' -> Invalid (Missing Special characters (!, @, #))
# 'xNJ@2HwnH' -> Valid
# 'H8b5Re' -> Invalid (Less than 8 characters)
# 'scLEw7fnUoM' -> Invalid (Missing Special characters (!, @, #))
# '6ot#Ywwf1' -> Valid
# 'TZ#WFXQbZ#EoB' -> Invalid (Missing Numbers)
# 'NW9CPo2mMtx' -> Invalid (Missing Special characters (!, @, #))
# 'hpw4#N8Ld' -> Valid
# 'L@w8sW' -> Invalid (Less than 8 characters)
# 'Xi6@3YU' -> Invalid (Less than 8 characters)
# 'qs#!@@skb' -> Invalid (Missing Uppercase letters, Numbers)
# '1OduIxmvdw' -> Invalid (Missing Special characters (!, @, #))
# 'Mmvz@' -> Invalid (Less than 8 characters)
# '5CaaSqJ3' -> Invalid (Missing Special characters (!, @, #))
# '3xnDf36HY' -> Invalid (Missing Special characters (!, @, #))
# 'UZE1wdB7' -> Invalid (Missing Special characters (!, @, #))
# 'Jsyy6uye9iwNQ' -> Invalid (Missing Special characters (!, @, #))
# 'vX5Ag#IDb#@' -> Valid
# 'XznSc#9x' -> Valid
# 'E@8ZQs' -> Invalid (Less than 8 characters)
# '52gvzFAibuA5c' -> Invalid (Missing Special characters (!, @, #))
# 'AjSzeIVUwV' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'IeJl7@7Ya' -> Valid
# 'E2!h@u' -> Invalid (Less than 8 characters)
# 'VGMBJF8La5UdW' -> Invalid (Missing Special characters (!, @, #))
# '#5VfDL4EK' -> Valid
# 'G!H21lTny' -> Valid
# 'K!6NILr' -> Invalid (Less than 8 characters)
# 'ftJz!WNNN#' -> Invalid (Missing Numbers)
# '6nXAlMtC96WD@L' -> Valid
# '!1oQj' -> Invalid (Less than 8 characters)
# 'Mp@a#' -> Invalid (Less than 8 characters)
# 'rWyJUcDpUE4' -> Invalid (Missing Special characters (!, @, #))
# '3oTkhcj!1Hg2!y' -> Valid
# 'FxYA5jjhd#' -> Valid
# '84Soz' -> Invalid (Less than 8 characters)
# '!TYi!z@8OtYT3' -> Valid
# 'lRGZ!' -> Invalid (Less than 8 characters)
# 'rlG9n5!' -> Invalid (Less than 8 characters)
# '!Env2' -> Invalid (Less than 8 characters)
# 'c4ZBbXugTBk@D' -> Valid
# '3l4N14ah!9' -> Valid
# 'Uv14Dcuzo' -> Invalid (Missing Special characters (!, @, #))
# 'IZy84V' -> Invalid (Less than 8 characters)
# '@srpQNlGdWmcuAK' -> Invalid (Missing Numbers)
# 'BxMTrrqUQR' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'h@##n5j' -> Invalid (Less than 8 characters)
# 'K1xchV' -> Invalid (Less than 8 characters)
# 'br63UMn' -> Invalid (Less than 8 characters)
# 'xTy9xja8Pc' -> Invalid (Missing Special characters (!, @, #))
# 'F!6RT' -> Invalid (Less than 8 characters)
# 'IXufV#3IATrkhN' -> Valid
# 'T5BL!5IOWPmX7Z' -> Valid
# 'ns!tYxPi' -> Invalid (Missing Numbers)
# 'FK#BigiA8305' -> Valid
# 'Wc1M3wE#pC#7' -> Valid
# 'Vu#1WSO8' -> Valid
# 'IW#sYD' -> Invalid (Less than 8 characters)
# 'RDaDm4kq9r' -> Invalid (Missing Special characters (!, @, #))
# 'bdlkwxratOqH' -> Invalid (Missing Numbers, Special characters (!, @, #))
# '9uRm@VDzc#5xd' -> Valid
# '0v9s!2@5X' -> Valid
# 'iKNW43#imKOUj' -> Valid
# '1xOQPP10#23Rz62' -> Valid
# 'cqQUDjBIj9FS' -> Invalid (Missing Special characters (!, @, #))
# 'Pyr0jxdi!Tr9' -> Valid
# 'u!F8rNprffVnW' -> Valid
# '6TgI1#Xmy' -> Valid
# 'SWyn!YK65Ic' -> Valid
# 'qs@zC' -> Invalid (Less than 8 characters)
# '1W#rRc' -> Invalid (Less than 8 characters)
# '33xbYBt6CuBh' -> Invalid (Missing Special characters (!, @, #))
# 'aTbKA!qir' -> Invalid (Missing Numbers)
# '#WXNAgU0fe@#tbc' -> Valid
# '@BpS!ghKU' -> Invalid (Missing Numbers)
# '7j2MaaLVBmN' -> Invalid (Missing Special characters (!, @, #))
# '5HhRv0yDwoBTSQL' -> Invalid (Missing Special characters (!, @, #))
# 'VFkjoHtMWJn' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'gZpG9SGU0ND' -> Invalid (Missing Special characters (!, @, #))
# '!oh!D2vtCYO0S7Q' -> Valid
# 'K!Y09BWy1DqJ' -> Valid
# '9I!@W2' -> Invalid (Less than 8 characters)
# 'o9QKus@2' -> Valid
# '#X@9J8I' -> Invalid (Less than 8 characters)
# '9z#alP@w1Eo29ur' -> Valid
# 'AYhbAEJYhv' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'Yy1!a' -> Invalid (Less than 8 characters)
# 'NhWjHj' -> Invalid (Less than 8 characters)
# '9pYQ4@' -> Invalid (Less than 8 characters)
# 'Peg05UhIK9UC' -> Invalid (Missing Special characters (!, @, #))
# '9Z5IWcG9QwNF' -> Invalid (Missing Special characters (!, @, #))
# 'I6paEdtL6dJhL' -> Invalid (Missing Special characters (!, @, #))
# 'F#sGypHV44A57C' -> Valid
# 'PQc6SV' -> Invalid (Less than 8 characters)
# '1Mo@6Qe7M' -> Valid
# '0piH!I' -> Invalid (Less than 8 characters)
# 'e4jKE1!Mi' -> Valid
# '1vlx3bxpzCaPZ' -> Invalid (Missing Special characters (!, @, #))
# 'tu7YjT0kb#MEdC' -> Valid
# 'lgvfc#5IzmN' -> Valid
# 'qjl#G' -> Invalid (Less than 8 characters)
# '!Yi2fY0j' -> Valid
# 'vTw#o' -> Invalid (Less than 8 characters)
# 'Wi#94r5@fg@o' -> Valid
# 'xHj3I3@07' -> Valid
# 'hqy1Hx4iOh' -> Invalid (Missing Special characters (!, @, #))
# 'dkL0OJM' -> Invalid (Less than 8 characters)
# '@76oD' -> Invalid (Less than 8 characters)
# '3eB@wvv' -> Invalid (Less than 8 characters)
# 'n0VwFXn@Fg' -> Valid
# 'ej#Mmf@NVhj0m7' -> Valid
# '4gR3KmKrI!fO' -> Valid
# '1WksgfSAf' -> Invalid (Missing Special characters (!, @, #))
# 'g#6NPn6LeO' -> Valid
# 'VPBlhs' -> Invalid (Less than 8 characters)
# 'hCK3lFn#i6gy' -> Valid
# 'W#m2E@1' -> Invalid (Less than 8 characters)
# 'JOnOABQH' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'glk3P5@po!KZ#' -> Valid
# 'uRk85lAv8!WlJSt' -> Valid
# 'Cw!2EO' -> Invalid (Less than 8 characters)
# 'gQ79FRU' -> Invalid (Less than 8 characters)
# 'ak!0Dxp' -> Invalid (Less than 8 characters)
# 'jdJaG0m8HvZU6j' -> Invalid (Missing Special characters (!, @, #))
# 'rq!Zh2jmFk#' -> Valid
# 'VZNR5UJ7J7@nry@' -> Valid
# 'c1em#P' -> Invalid (Less than 8 characters)
# 'B!#XOZQ' -> Invalid (Less than 8 characters)
# '!we5ox#6T' -> Valid
# '2T7zI@3zq' -> Valid
# '3tdHM23aePZ!dQ' -> Valid
# 'MIRCjX1dhAk3' -> Invalid (Missing Special characters (!, @, #))
# '48liTVk0#LTGHt' -> Valid
# '7#VccQYRbGYwglS' -> Valid
# 'W5!!SN57' -> Invalid (Missing Lowercase letters)
# '5mcOT5aq' -> Invalid (Missing Special characters (!, @, #))
# 'kd3xsQ' -> Invalid (Less than 8 characters)
# 'ea6ME' -> Invalid (Less than 8 characters)
# '6e#Ff5ju@YdG' -> Valid
# 'H!p8k' -> Invalid (Less than 8 characters)
# '2@GfTG8ykyWQ' -> Valid
# '3gcG9AI@ODEuVbe' -> Valid
# 'fhV!7@Vo31IDFJ' -> Valid
# 'co503KI#U9KK@' -> Valid
# '0yW!9r9uRc' -> Valid
# 'D0M1F#sI9BqOC1' -> Valid
# 'P3Wsg@aC' -> Valid
# 'JfLp#YEgl' -> Invalid (Missing Numbers)
# 'FofF6M' -> Invalid (Less than 8 characters)
# 'r3mxvDfnXK' -> Invalid (Missing Special characters (!, @, #))
# 'y!z10a' -> Invalid (Less than 8 characters)
# '7fcT720k' -> Invalid (Missing Special characters (!, @, #))
# '8ElKW' -> Invalid (Less than 8 characters)
# 'XweYq6EII5NxO' -> Invalid (Missing Special characters (!, @, #))
# 'JR0KO' -> Invalid (Less than 8 characters)
# 'CFB@IrzD!pfEg' -> Invalid (Missing Numbers)
# 'Yv7EHgyAxK5' -> Invalid (Missing Special characters (!, @, #))
# '8m8#LjM3' -> Valid
# '3hhFNbGIy!Yzi' -> Valid
# 'vg!rJJS@1eBg' -> Valid
# 'Zo6#5p' -> Invalid (Less than 8 characters)
# 'D5xD8ky' -> Invalid (Less than 8 characters)
# 'uZ!uu' -> Invalid (Less than 8 characters)
# 'wiS2@' -> Invalid (Less than 8 characters)
# '0lrM2X#g' -> Valid
# 'JucHm#rxdiM1v' -> Valid
# 'tyrwLUl8!iu' -> Valid
# 'Vl7z#g' -> Invalid (Less than 8 characters)
# '#2gdPetu2R' -> Valid
# 'WVX70i' -> Invalid (Less than 8 characters)
# 'DUb@gjd' -> Invalid (Less than 8 characters)
# '2nOwsV7Tk6uFOL' -> Invalid (Missing Special characters (!, @, #))
# 'Uk@sDdr#J' -> Invalid (Missing Numbers)
# 'WqQZ8y' -> Invalid (Less than 8 characters)
# 'h3pyNt' -> Invalid (Less than 8 characters)
# 'm!ULw' -> Invalid (Less than 8 characters)
# 'Z9og3k#Xm8' -> Valid
# 'aaC!hI' -> Invalid (Less than 8 characters)
# '#70jc2i' -> Invalid (Less than 8 characters)
# 'm5kKuAakhoFjdIM' -> Invalid (Missing Special characters (!, @, #))
# '19kX6zbe@iqOR' -> Valid
# 'a!jEWXyy40eQJ' -> Valid
# '7C25#rTV' -> Valid
# '@MY@Uuq' -> Invalid (Less than 8 characters)
# 'OFnAlT' -> Invalid (Less than 8 characters)
# 'rSC2Yp#XPQL' -> Valid
# 'ZlwDE00GgcPD' -> Invalid (Missing Special characters (!, @, #))
# '0nlW4lTekLPrMg2' -> Invalid (Missing Special characters (!, @, #))
# '!bYV!ao1sP' -> Valid
# 'ijooOIsLI36Qa@' -> Valid
# 'A5KK8ym#' -> Valid
# 'Qp2rwYiRl' -> Invalid (Missing Special characters (!, @, #))
# 'RGIP0BwxThTwg' -> Invalid (Missing Special characters (!, @, #))
# 'Q@POSz!6GEqxz' -> Valid
# 'fMdup!B' -> Invalid (Less than 8 characters)
# 'ESHRjfQ2RtxA' -> Invalid (Missing Special characters (!, @, #))
# '2Z9Bg1Pn' -> Invalid (Missing Special characters (!, @, #))
# '04RfC5Ri4F' -> Invalid (Missing Special characters (!, @, #))
# 'Ohti4hCA75p@KyW' -> Valid
# '5vDXC3' -> Invalid (Less than 8 characters)
# 'ZTZONfue2rE#RD2' -> Valid
# 'gDlfvR' -> Invalid (Less than 8 characters)
# 'JrWnhx88E@sz#BP' -> Valid
# '2U4YWXnq@RIa5i' -> Valid
# '@!FXhAnEXBs8Y' -> Valid
# 'P0PuwAce' -> Invalid (Missing Special characters (!, @, #))
# 'Fy03RUt@F6H8HH' -> Valid
# 'bbH5gex' -> Invalid (Less than 8 characters)
# 'up8sZkYS8DWePga' -> Invalid (Missing Special characters (!, @, #))
# '!6JVm6LAo5dc' -> Valid
# 'X5QR!r4cxv2ws' -> Valid
# '!48vW' -> Invalid (Less than 8 characters)
# 'Pl8a2j!TKj4' -> Valid
# 'c39ZeDslql5nrf' -> Invalid (Missing Special characters (!, @, #))
# 'E!h!Day' -> Invalid (Less than 8 characters)
# 'PtRoH2smB@j2yvh' -> Valid
# 'AJ1vq@OirJm6Ad' -> Valid
# 'lR#opFMSOBtVFlN' -> Invalid (Missing Numbers)
# 'ageBRHep' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'f##PNjZ' -> Invalid (Less than 8 characters)
# 'Ct4qJbTY#' -> Valid
# '@XfPIr' -> Invalid (Less than 8 characters)
# 'tnx!1KsI!pXhzVH' -> Valid
# 'mMK0sM7B8xK' -> Invalid (Missing Special characters (!, @, #))
# 'O8LTpqLW' -> Invalid (Missing Special characters (!, @, #))
# 'V3L6qh' -> Invalid (Less than 8 characters)
# 'ZRIVXBgVa@dOs' -> Invalid (Missing Numbers)
# 'KqwQPzhRgrP' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'tz7tz3NXP@O#' -> Valid
# 'eE#lJb17' -> Valid
# '#CvWjnqGeKa' -> Invalid (Missing Numbers)
# 'oWW2#sAmP' -> Valid
# 'vpEv#' -> Invalid (Less than 8 characters)
# 'JmmJi80EZiDR' -> Invalid (Missing Special characters (!, @, #))
# 'M5fau' -> Invalid (Less than 8 characters)
# 'LYSlHFvvPAQha0' -> Invalid (Missing Special characters (!, @, #))
# 'T!wPZKq@5k4b' -> Valid
# '#C!emod#8Epm' -> Valid
# 'd1w1Au' -> Invalid (Less than 8 characters)
# 'ZUQXvtHQf6' -> Invalid (Missing Special characters (!, @, #))
# '7kC6i@46ulud' -> Valid
# 'OT!hcAtt5' -> Valid
# 'GamDrgTe!1xZ' -> Valid
# 'hXT!gU' -> Invalid (Less than 8 characters)
# 'UUWmSiF3cD33uPU' -> Invalid (Missing Special characters (!, @, #))
# 'a#j7V1' -> Invalid (Less than 8 characters)
# 'sK26!5kA' -> Valid
# '#Gwc6Ke' -> Invalid (Less than 8 characters)
# '3#CQg' -> Invalid (Less than 8 characters)
# 'APlcWTdmo' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'b@9l9DE' -> Invalid (Less than 8 characters)
# 'EgiV9Agj' -> Invalid (Missing Special characters (!, @, #))
# 'aLwaKeV' -> Invalid (Less than 8 characters)
# '9E7hdQ1JMQ8qCoi' -> Invalid (Missing Special characters (!, @, #))
# '4COZi@0' -> Invalid (Less than 8 characters)
# 'hVYWUGwa' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'Q6iu7Mh' -> Invalid (Less than 8 characters)
# 'whR!@Wwaj!i' -> Invalid (Missing Numbers)
# 'C!0J@7lkw' -> Valid
# '@QCREeaq8' -> Valid
# 'FIP4x!@RclW' -> Valid
# 'ThHPMJHUEmCsESa' -> Invalid (Missing Numbers, Special characters (!, @, #))
# '#!dSFjJh43' -> Valid
# 'KBlQn#EHg' -> Invalid (Missing Numbers)
# 'STfWDFz' -> Invalid (Less than 8 characters)
# 'hI!49QiVGgp' -> Valid
# '4tUK@ZZg' -> Valid
# 'jNsaN0qf' -> Invalid (Missing Special characters (!, @, #))
# '2hKNun8sR' -> Invalid (Missing Special characters (!, @, #))
# 'UnrfqvwSpuOh' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'D1wumkKbN4lhF#!' -> Valid
# '70WJB@@' -> Invalid (Less than 8 characters)
# 'PFj4wWf!EGmZ#cx' -> Valid
# 'eHjVvhjJN!5TTx' -> Valid
# 'ggIf4buJ#rL' -> Valid
# 'mSGNhfYhsq66f!' -> Valid
# 'IU7Jr8sw' -> Invalid (Missing Special characters (!, @, #))
# 'c5kmjWIdoNtxuD5' -> Invalid (Missing Special characters (!, @, #))
# 'NY!o9KOOP' -> Valid
# 'SUqmMc@KvIk' -> Invalid (Missing Numbers)
# 'lS!!@' -> Invalid (Less than 8 characters)
# 'TQpi9XV#' -> Valid
# 'aeqg7jzc#' -> Invalid (Missing Uppercase letters)
# 'bbkZb' -> Invalid (Less than 8 characters)
# 'ghz@JuG9aUH#rG' -> Valid
# 'MMglTK21dBtOq' -> Invalid (Missing Special characters (!, @, #))
# 'RYqxA1bzn8rX3Vi' -> Invalid (Missing Special characters (!, @, #))
# 'me4aqM!2Pin#Zvw' -> Valid
# 'w#O96K' -> Invalid (Less than 8 characters)
# 'mO7xfRyay5UaXH' -> Invalid (Missing Special characters (!, @, #))
# 'UUS!k' -> Invalid (Less than 8 characters)
# 'h@fD45btAHI49' -> Valid
# '!sHWMPUxo#' -> Invalid (Missing Numbers)
# '!l#cZY3R3pQc' -> Valid
# 'PPZ14HCZq#zEq' -> Valid
# 'VXe!ppEIN7JOe' -> Valid
# 'qNGiD' -> Invalid (Less than 8 characters)
# 'IZ#7!WPmSTE' -> Valid
# 'A@xictGIvWE7T' -> Valid
# 'KO9@ncKi' -> Valid
# 'r@5lQ' -> Invalid (Less than 8 characters)
# '99N#n7yk9' -> Valid
# 'pT7ms' -> Invalid (Less than 8 characters)
# '2xvac5RgoMDI' -> Invalid (Missing Special characters (!, @, #))
# 'JS3UkKok' -> Invalid (Missing Special characters (!, @, #))
# '8WpOcZnBlTumU1Q' -> Invalid (Missing Special characters (!, @, #))
# 'Z!YHP!A1' -> Invalid (Missing Lowercase letters)
# 'u334Q' -> Invalid (Less than 8 characters)
# '3!pONZBdSzN' -> Valid
# '0d!XY' -> Invalid (Less than 8 characters)
# '71dCj8ODM!#yk' -> Valid
# 'wlMT8Ts2' -> Invalid (Missing Special characters (!, @, #))
# 'R6s2Q4i' -> Invalid (Less than 8 characters)
# 'T18z97xO' -> Invalid (Missing Special characters (!, @, #))
# 'C@m8eK2h1to' -> Valid
# 'XD3W!va8S' -> Valid
# '@jyg7E9W' -> Valid
# 'd#u1#QsrdpR' -> Valid
# '7Ry2PBv@' -> Valid
# 'D!kw8iepP7q!V' -> Valid
# '!mcgKE' -> Invalid (Less than 8 characters)
# '2GgjUtXROTt!' -> Valid
# 'Ie!4rjI@a' -> Valid
# 'BnzfYmeV' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'v44Vx2UK651G6' -> Invalid (Missing Special characters (!, @, #))
# 'b4zLG' -> Invalid (Less than 8 characters)
# 'ywCdX3AkyML3z0r' -> Invalid (Missing Special characters (!, @, #))
# 'd81uVDXgy#F' -> Valid
# 'tH#@s@yrM5cGL' -> Valid
# 'TOTkOR7f67U' -> Invalid (Missing Special characters (!, @, #))
# 'Vi@n@6' -> Invalid (Less than 8 characters)
# '@uD2Z' -> Invalid (Less than 8 characters)
# '8xq2fgM@IP' -> Valid
# '9jHC@5' -> Invalid (Less than 8 characters)
# 'Kn4FoRXQqI9jxif' -> Invalid (Missing Special characters (!, @, #))
# 'SM8i!' -> Invalid (Less than 8 characters)
# 'Vikb6uwo2XxY' -> Invalid (Missing Special characters (!, @, #))
# '9YxwpNH@HRUI' -> Valid
# 'O!2yr' -> Invalid (Less than 8 characters)
# '2vb13iV4PS' -> Invalid (Missing Special characters (!, @, #))
# 'A!88Eu8uMaxEb6' -> Valid
# 'sq72Zs#' -> Invalid (Less than 8 characters)
# 'HgUDaLa#748buNb' -> Valid
# 'N#vwfwjd!9uF4' -> Valid
# 'pehK3av9MfG6Dq' -> Invalid (Missing Special characters (!, @, #))
# 'YomYh' -> Invalid (Less than 8 characters)
# 'SCiNES5KLPh5gF' -> Invalid (Missing Special characters (!, @, #))
# 'pk#dTf' -> Invalid (Less than 8 characters)
# 'I5Z6onr' -> Invalid (Less than 8 characters)
# 'T1hwBTxA0' -> Invalid (Missing Special characters (!, @, #))
# 'YrB7kbQYPPmP5y@' -> Valid
# 'gx#Vz49UeKx8rb' -> Valid
# 'x6uZR@' -> Invalid (Less than 8 characters)
# 'hRWv8' -> Invalid (Less than 8 characters)
# 'HpL!GyQ' -> Invalid (Less than 8 characters)
# 'RXj2f!UWLfP8q' -> Valid
# 'f8CF@DhBtwd4D0Z' -> Valid
# 'mYz@DnQ2' -> Valid
# 'lnr8@ba8#bAO8' -> Valid
# 'A@2#j1O' -> Invalid (Less than 8 characters)
# '1SfFp6AX' -> Invalid (Missing Special characters (!, @, #))
# '1T6WDh0' -> Invalid (Less than 8 characters)
# 'lOOvx9N2R' -> Invalid (Missing Special characters (!, @, #))
# 'Huz8FgbpJ' -> Invalid (Missing Special characters (!, @, #))
# 'a7T3KN' -> Invalid (Less than 8 characters)
# 'aDR5PYiJ!ElsR' -> Valid
# 'BUL3@8' -> Invalid (Less than 8 characters)
# 'PtFmOskwXNH5a' -> Invalid (Missing Special characters (!, @, #))
# 'lp!r!5ii' -> Invalid (Missing Uppercase letters)
# 'v@aIid68@' -> Valid
# 'K9@5E' -> Invalid (Less than 8 characters)
# 'BM#k3BxE4prlLGW' -> Valid
# 'L#a6UupCxJGA' -> Valid
# 'rFDgyLCtcne@0h' -> Valid
# 'cwuYYVvb@Um0L' -> Valid
# 'vQI2EYtTCLNeE' -> Invalid (Missing Special characters (!, @, #))
# 'tkT9k' -> Invalid (Less than 8 characters)
# 'yDy8t#8Hek' -> Valid
# '#uwvTLu7Mi4i' -> Valid
# 'GJf6CquOJ#' -> Valid
# 'B9LdA7Rtn2' -> Invalid (Missing Special characters (!, @, #))
# 'JT1ZDy@sthva' -> Valid
# 'U@!Ry6XXDu4' -> Valid
# 'SZy@IA6Zxv7' -> Valid
# '6jjJN' -> Invalid (Less than 8 characters)
# 'I#80e!I4CY63W' -> Valid
# '!fJU8WG95x' -> Valid
# 'LA4I3#g2st4' -> Valid
# 'I38mIbcJ!aJ' -> Valid
# '3dV1QfvSKU' -> Invalid (Missing Special characters (!, @, #))
# 'iIV8@xY' -> Invalid (Less than 8 characters)
# 'vXxZdbo5G!' -> Valid
# 'dFJdrFaU!GCtDm4' -> Valid
# 'S0SYp3zGGZL!Cz3' -> Valid
# 'F9M@8KJ' -> Invalid (Less than 8 characters)
# 'jCy1r3q5g#' -> Valid
# 'W5Y0@a' -> Invalid (Less than 8 characters)
# 'ObsKP9UfnvqjyMJ' -> Invalid (Missing Special characters (!, @, #))
# 'B1cPtU' -> Invalid (Less than 8 characters)
# 'ai06WihDVacZ0' -> Invalid (Missing Special characters (!, @, #))
# 'BkxYpJHIg7#0R4' -> Valid
# '@3Tb#' -> Invalid (Less than 8 characters)
# 'D7X2Umqe#' -> Valid
# '@gdgDhE@qYW' -> Invalid (Missing Numbers)
# 'qNive!I!lXNl' -> Invalid (Missing Numbers)
# 'f8InROeoSMUnl' -> Invalid (Missing Special characters (!, @, #))
# 'K9rJ38trdDZp7' -> Invalid (Missing Special characters (!, @, #))
# 'i!dHbJ' -> Invalid (Less than 8 characters)
# '!F#gL8Ch0yFp7YF' -> Valid
# '@uUaXPpBoKoZHhn' -> Invalid (Missing Numbers)
# 'nBZRyp6!ihe94L' -> Valid
# 'jmTZI' -> Invalid (Less than 8 characters)
# 'hHPelj1Qyy' -> Invalid (Missing Special characters (!, @, #))
# 'F8OJhEJN@5bYpx' -> Valid
# 'fwpjUSnX@FBaX9#' -> Valid
# 'NPhuW' -> Invalid (Less than 8 characters)
# 'dC3kaJJV' -> Invalid (Missing Special characters (!, @, #))
# 'ps981uryOTAW' -> Invalid (Missing Special characters (!, @, #))
# 'brjFdU9G' -> Invalid (Missing Special characters (!, @, #))
# 'WXdS4GH@s' -> Valid
# 'ipb5mp@' -> Invalid (Less than 8 characters)
# 'MYTR0M8u' -> Invalid (Missing Special characters (!, @, #))
# 'tz7CE#8u' -> Valid
# '1Af1SiflfLun3x' -> Invalid (Missing Special characters (!, @, #))
# 'gbbmmuFdPOFfG' -> Invalid (Missing Numbers, Special characters (!, @, #))
# '2Cy3r3!v65Q' -> Valid
# '92VV!yG1yy' -> Valid
# 'BHZyq@bb' -> Invalid (Missing Numbers)
# 'iSLxp6w4V' -> Invalid (Missing Special characters (!, @, #))
# 'oxATBG' -> Invalid (Less than 8 characters)
# 'RIdE4!' -> Invalid (Less than 8 characters)
# '1dMrkYn0spf' -> Invalid (Missing Special characters (!, @, #))
# '1!cLpyW#JXZ' -> Valid
# '#aol5bj' -> Invalid (Less than 8 characters)
# 'j!UjYDj6OR' -> Valid
# 'PJv9@x' -> Invalid (Less than 8 characters)
# 'IuUqi6U' -> Invalid (Less than 8 characters)
# 'kWrmwG' -> Invalid (Less than 8 characters)
# 'uqbJwa!bE@TB' -> Invalid (Missing Numbers)
# 'dGSGYJqL#x8NMDL' -> Valid
# '44BF8U#YO!C' -> Invalid (Missing Lowercase letters)
# 'Y05i#FNL@1' -> Valid
# '#tfv5OMgwjM' -> Valid
# 'Mt@QaVAbc4' -> Valid
# 'KbCM7oNf#s' -> Valid
# 'SKN7t' -> Invalid (Less than 8 characters)
# 'Ckri@Gh2xSE' -> Valid
# 'eHeprNf' -> Invalid (Less than 8 characters)
# 'SPTSqC4eB' -> Invalid (Missing Special characters (!, @, #))
# '@fmdUVTZHGK!U8' -> Valid
# 'trk7op0lf1HiQ' -> Invalid (Missing Special characters (!, @, #))
# 'gHQVM!03W' -> Valid
# '6JuvbI3@9gNylkj' -> Valid
# 'kAK60WttjO3FDd!' -> Valid
# 'WCTCaaRQ' -> Invalid (Missing Numbers, Special characters (!, @, #))
# '1kiSR#Nj' -> Valid
# 'sMgNSIXBd#8A' -> Valid
# 'M2!cOKiGFVd1y' -> Valid
# 'qb7lN74kkTkKC!6' -> Valid
# '!mx7VC2cobd7zf' -> Valid
# 'j2Ncd@2T#t4jS8' -> Valid
# '9X4EG@m3zb5g' -> Valid
# 'EFLo71@Wb' -> Valid
# 'RrcLSM!fSD#o@5N' -> Valid
# 'IkJbFOP6' -> Invalid (Missing Special characters (!, @, #))
# 'cJVMIYbL@u9' -> Valid
# '9@!BTxTU' -> Valid
# 'qMvAsek5' -> Invalid (Missing Special characters (!, @, #))
# 'vA9!H' -> Invalid (Less than 8 characters)
# 'rzl!0YPE1#xWRsR' -> Valid
# 'ga3dCZarZ' -> Invalid (Missing Special characters (!, @, #))
# 'S5YNF8bbky@' -> Valid
# 'FE4rJ' -> Invalid (Less than 8 characters)
# 'c0L8CQq!' -> Valid
# 'ntudYfc3BSN#EOw' -> Valid
# 'mFDF3Uy@' -> Valid
# 'E@DexqsA' -> Invalid (Missing Numbers)
# 'et@fY' -> Invalid (Less than 8 characters)
# 'gAm@wzE' -> Invalid (Less than 8 characters)
# 'TjUpnMWnt6YXo5z' -> Invalid (Missing Special characters (!, @, #))
# 'FGFQ9@EP' -> Invalid (Missing Lowercase letters)
# 'BY6KD9S0J!' -> Invalid (Missing Lowercase letters)
# 'kQV1mq9R' -> Invalid (Missing Special characters (!, @, #))
# '!WZzx5' -> Invalid (Less than 8 characters)
# 'TVgcfurOS' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'v7cI2' -> Invalid (Less than 8 characters)
# 'Yka01K' -> Invalid (Less than 8 characters)
# 'xt!zTX!KN' -> Invalid (Missing Numbers)
# '9C3L!E9!eXK7d' -> Valid
# '#uO7i' -> Invalid (Less than 8 characters)
# 'B5rDXu!0l' -> Valid
# '7OVuYn1eB' -> Invalid (Missing Special characters (!, @, #))
# 'WmG#C#bd0BUl' -> Valid
# 'iSrzV4' -> Invalid (Less than 8 characters)
# 'aNNmU6' -> Invalid (Less than 8 characters)
# '7S5hp' -> Invalid (Less than 8 characters)
# '8IfA8O' -> Invalid (Less than 8 characters)
# 'PbPzC#lm4D' -> Valid
# 'hR#WvpZ!' -> Invalid (Missing Numbers)
# 'aJGy#PP3@uX' -> Valid
# 'h@6S63yi' -> Valid
# '@8kLxTnqTbZ@gq' -> Valid
# '#ot@3cbVx#' -> Valid
# 'u@JC0cx@m' -> Valid
# 'NDil8y#bSK@@' -> Valid
# '8kz@6h' -> Invalid (Less than 8 characters)
# '6OV7aEu58!' -> Valid
# 't7n10@S' -> Invalid (Less than 8 characters)
# 's#h0Ld' -> Invalid (Less than 8 characters)
# 'JIMV2Oql6teBBF2' -> Invalid (Missing Special characters (!, @, #))
# '69wFk#cSdf5P8' -> Valid
# 's1s4!h' -> Invalid (Less than 8 characters)
# 'H@ajj' -> Invalid (Less than 8 characters)
# '@eopWF' -> Invalid (Less than 8 characters)
# 'xb8U8bmOy5rVs' -> Invalid (Missing Special characters (!, @, #))
# 'Y8@!50kuH8o4w' -> Valid
# 'gqxuj!itt' -> Invalid (Missing Uppercase letters, Numbers)
# 'pAqbZxwkbJ' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'BTZ6m4d5I!MjY' -> Valid
# 's8S#PeACOT' -> Valid
# 'Fo#BSn7CE5t' -> Valid
# 'n#TRQxkSe' -> Invalid (Missing Numbers)
# 's@e#u3nLf8sZ' -> Valid
# '994n!T' -> Invalid (Less than 8 characters)
# 'AM!4EbhN8T' -> Valid
# 'pARjKS4Z9lnT' -> Invalid (Missing Special characters (!, @, #))
# 'zy#0k0uKINTt#' -> Valid
# 'PiwR0hMd' -> Invalid (Missing Special characters (!, @, #))
# 'VAkValq#esW' -> Invalid (Missing Numbers)
# 'Fq##M4fKMW13' -> Valid
# 'SS@5RYSx' -> Valid
# 'PmuX!QVw4of3K' -> Valid
# 'c252oSIz3uMDe9n' -> Invalid (Missing Special characters (!, @, #))
# 'n@2Wzn9' -> Invalid (Less than 8 characters)
# 'QWQZTr@9Hsx3' -> Valid
# '8RxZEg8K3NkWT' -> Invalid (Missing Special characters (!, @, #))
# 'LzCH3vfFe8Y!XrJ' -> Valid
# 'yCAUqu#301' -> Valid
# 'dwjGec#IS' -> Invalid (Missing Numbers)
# 'Hc4!R' -> Invalid (Less than 8 characters)
# 'zw@fJ9' -> Invalid (Less than 8 characters)
# '@Iw#9' -> Invalid (Less than 8 characters)
# '0U0pVg7lu' -> Invalid (Missing Special characters (!, @, #))
# 'c#57p' -> Invalid (Less than 8 characters)
# 'gA7ltDp' -> Invalid (Less than 8 characters)
# 'bqVAMm' -> Invalid (Less than 8 characters)
# 'UVLPu' -> Invalid (Less than 8 characters)
# 'WCG@32WrCi2yj!' -> Valid
# 'M2fb!' -> Invalid (Less than 8 characters)
# 'cJvE3YlcCEq1#M' -> Valid
# '@xTFPNk!tG!q!A' -> Invalid (Missing Numbers)
# 'fPZ9V!sAj' -> Valid
# '024XV83ENqSlK0' -> Invalid (Missing Special characters (!, @, #))
# 'bWU3qTNtGgdAzvU' -> Invalid (Missing Special characters (!, @, #))
# 'N@g0Il1' -> Invalid (Less than 8 characters)
# 'Gv2!O' -> Invalid (Less than 8 characters)
# 'no@BefAqOm3gna!' -> Valid
# '2Gk#tX#Ik8D8' -> Valid
# '7BJuQv' -> Invalid (Less than 8 characters)
# 'yYT2CM' -> Invalid (Less than 8 characters)
# 'VehuWP5FOb0' -> Invalid (Missing Special characters (!, @, #))
# '7AKAdp7uFRiSs' -> Invalid (Missing Special characters (!, @, #))
# 'k@SNK!pY9FvI' -> Valid
# 'YTZ9ak2p47ABv' -> Invalid (Missing Special characters (!, @, #))
# '@FxG32ik8DMFXxy' -> Valid
# 'K5XpmgaOwDLX' -> Invalid (Missing Special characters (!, @, #))
# 'BqSbPeS0j7Mo0R' -> Invalid (Missing Special characters (!, @, #))
# '4FCT9' -> Invalid (Less than 8 characters)
# 'KoiHi!8z' -> Valid
# 'FNgL@#BICeaiGi' -> Invalid (Missing Numbers)
# 'H0on#gg19' -> Valid
# 'Jq5bV08KjrvtL' -> Invalid (Missing Special characters (!, @, #))
# 'JI!Ll7iZOW' -> Valid
# 'FHDAw#4L' -> Valid
# 'Kkiux4zK' -> Invalid (Missing Special characters (!, @, #))
# '!Or4Q!7L0' -> Valid
# '@qkRmp893ce' -> Valid
# '#Nc77#2CU2vu0I' -> Valid
# 'jU#Ouvv!R0pd#' -> Valid
# '5!Jp6vr2wB' -> Valid
# 'Q7RC@@ZUJ4zkzaI' -> Valid
# 'ti#9XzlUI0O' -> Valid
# 'uX6J6U!TZWbLst' -> Valid
# 'LOg25DObQVnTi' -> Invalid (Missing Special characters (!, @, #))
# 'Qarx!V898ZIuSST' -> Valid
# 'eNA!k' -> Invalid (Less than 8 characters)
# 'x!qnXUYT' -> Invalid (Missing Numbers)
# 'LxYp12S!3@04lWD' -> Valid
# 'OR54kXsWG' -> Invalid (Missing Special characters (!, @, #))
# 'h8nc8RoP!4nox!R' -> Valid
# 'MpSQK!!W' -> Invalid (Missing Numbers)
# 'ruP@PWo@lhDoI2' -> Valid
# '8ww!2dh3CVS' -> Valid
# 'tVhfZy' -> Invalid (Less than 8 characters)
# '7kikt@iFJQl' -> Valid
# 'zFTgrV!VHR' -> Invalid (Missing Numbers)
# 'MGOANUvYR8bGL' -> Invalid (Missing Special characters (!, @, #))
# 'cPc07eQBRcnWzw' -> Invalid (Missing Special characters (!, @, #))
# 'yxMqk4UFQMes2O9' -> Invalid (Missing Special characters (!, @, #))
# 'maFLrgI#Wv' -> Invalid (Missing Numbers)
# '7UGsGhEId' -> Invalid (Missing Special characters (!, @, #))
# 'AhRs5SLRFk7J' -> Invalid (Missing Special characters (!, @, #))
# 'yA@Jp!R3WCLlt' -> Valid
# 'Ztv0TF@biN6' -> Valid
# 'f!FqFleZlduRC' -> Invalid (Missing Numbers)
# 'f0S@#mW!tLi@Q' -> Valid
# 'wP03c#KO8bQ#yy' -> Valid
# 'r5H7Cq!' -> Invalid (Less than 8 characters)
# 'vAkENGQdqII' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'MlFgr' -> Invalid (Less than 8 characters)
# 'rP2V@#' -> Invalid (Less than 8 characters)
# 'DdaQvAftZ' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'Nv1WN925!CfSYdC' -> Valid
# 'iBC#Qn' -> Invalid (Less than 8 characters)
# '@QfHws' -> Invalid (Less than 8 characters)
# 'cCIRk' -> Invalid (Less than 8 characters)
# 'G9u5qTVN#H' -> Valid
# '@qEIVo5K!6c' -> Valid
# 'JYsR!f' -> Invalid (Less than 8 characters)
# 'nEKZTwx' -> Invalid (Less than 8 characters)
# '4mnplUg#tWrr2xn' -> Valid
# 'A43iE!35b3' -> Valid
# 'XZtTq!' -> Invalid (Less than 8 characters)
# 'z!m77R' -> Invalid (Less than 8 characters)
# 'zmt0q6X' -> Invalid (Less than 8 characters)
# 'DnaBCdPI' -> Invalid (Missing Numbers, Special characters (!, @, #))
# 'mwV6Xsfz0Yi' -> Invalid (Missing Special characters (!, @, #))
# 'c5sFJ2J#UdbjX' -> Valid
# '3bDjzHwJbCXOM2' -> Invalid (Missing Special characters (!, @, #))
# 'MOzrRc@GrRmx' -> Invalid (Missing Numbers)
# 'GwqC9O#WPO' -> Valid
# 'w@abVzHNA6fNCI' -> Valid
# '2KmC@' -> Invalid (Less than 8 characters)
# '4G8O!' -> Invalid (Less than 8 characters)
# '!t9R2FKuLG0O8' -> Valid
# 'w9mxl#dMY69' -> Valid
# 'lWA550Caokezr' -> Invalid (Missing Special characters (!, @, #))
# 'SH2eu0w5vL' -> Invalid (Missing Special characters (!, @, #))
# 'Ax8#I' -> Invalid (Less than 8 characters)
# 'EoXQzX4Cl' -> Invalid (Missing Special characters (!, @, #))
# '23gV#W' -> Invalid (Less than 8 characters)
# 'dZ0yLw' -> Invalid (Less than 8 characters)
# '5hoLCXumhH' -> Invalid (Missing Special characters (!, @, #))
# 'r5oO!zp' -> Invalid (Less than 8 characters)
# 'ak7yx#KYMC' -> Valid
# 'Cu3K!7ztqQrC034' -> Valid
# 'DAZtTPN9@V#oBi' -> Valid
# '#p1@6Yy9HwZ4O' -> Valid
# 'kC!Edi' -> Invalid (Less than 8 characters)
# 'aZXfb@f9IFoX0a' -> Valid
# '2hqfFrm7' -> Invalid (Missing Special characters (!, @, #))
# 'k@tlK9I' -> Invalid (Less than 8 characters)
# 'VqO@vD8gEqWh' -> Valid
# 'P2xWFqV2' -> Invalid (Missing Special characters (!, @, #))
# 'CbtzeUaa53@a160' -> Valid
# 'QJC#YU' -> Invalid (Less than 8 characters)
# '7O1QSQqc' -> Invalid (Missing Special characters (!, @, #))
# 'w2M@8' -> Invalid (Less than 8 characters)
#
# Summary:
# Total Valid Passwords: 430
# Total Invalid Passwords: 570
